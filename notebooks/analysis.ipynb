# %%
import pandas as pd

df = pd.read_csv('../data/JC-202605-citibike-tripdata.csv')
print(df.shape)
df.head()
# Out:
# (95350, 13)
#             ride_id  rideable_type               started_at  \
# 0  82D531671F07CEE6  electric_bike  2026-05-29 09:21:48.430
# 1  BC3888F5C97704D9   classic_bike  2026-05-30 15:39:35.546
# 2  D0AF14E7B533B3D0   classic_bike  2026-05-25 22:13:29.172
# 3  AB6C74D6382A3361   classic_bike  2026-05-07 10:06:14.421
# 4  663D67EA2B3FBEA0  electric_bike  2026-05-23 19:52:24.311
#
#                   ended_at                 start_station_name  \
# 0  2026-05-29 09:46:51.394  14 St Ferry - 14 St & Shipyard Ln
# 1  2026-05-30 15:42:41.986                        Paulus Hook
# 2  2026-05-25 22:16:12.461          Washington St & Morgan St
# 3  2026-05-07 10:13:30.958                       Newport PATH
# 4  2026-05-23 20:22:34.932                         Bergen Ave
#
#   start_station_id              end_station_name end_station_id  start_lat  \
# 0            HB202       E 53 St & Lexington Ave        6617.09  40.752961
# ...
